# %% [markdown]
# # Stroke Prediction

# %%
import pandas as pd

# %%
df = pd.read_csv("stroke.csv")

# %%
df.tail()
# Out:
#          id  gender   age  hypertension  heart_disease ever_married  \
# 5105  18234  Female  80.0             1              0          Yes
# 5106  44873  Female  81.0             0              0          Yes
# 5107  19723  Female  35.0             0              0          Yes
# 5108  37544    Male  51.0             0              0          Yes
# 5109  44679  Female  44.0             0              0          Yes
#
#           work_type Residence_type  avg_glucose_level   bmi   smoking_status  \
# 5105        Private          Urban              83.75   NaN     never smoked
# 5106  Self-employed          Urban             125.20  40.0     never smoked
# 5107  Self-employed          Rural              82.99  30.6     never smoked
# 5108        Private          Rural             166.29  25.6  formerly smoked
# 5109       Govt_job          Urban              85.28  26.2          Unknown
#
#       stroke
# 5105       0
# 5106       0
# 5107       0
# 5108       0
# 5109       0

# %%
df.drop(columns = "id")
# Out:
#       gender   age  hypertension  heart_disease ever_married      work_type  \
# 0       Male  67.0             0              1          Yes        Private
# 1     Female  61.0             0              0          Yes  Self-employed
# 2       Male  80.0             0              1          Yes        Private
# 3     Female  49.0             0              0          Yes        Private
# 4     Female  79.0             1              0          Yes  Self-employed
# ...      ...   ...           ...            ...          ...            ...
# 5105  Female  80.0             1              0          Yes        Private
# 5106  Female  81.0             0              0          Yes  Self-employed
# 5107  Female  35.0             0              0          Yes  Self-employed
# 5108    Male  51.0             0              0          Yes        Private
# 5109  Female  44.0             0              0          Yes       Govt_job
#
# ...

# %%
len(df["bmi"])
# Out:
# 5110

# %%
df["bmi"][2]
# Out:
# 32.5

# %%
for i in range(5110):
    if(df["bmi"][i] == "NaN"):
        df["bmi"][i] = 0
df
# Out:
#          id  gender   age  hypertension  heart_disease ever_married  \
# 0      9046    Male  67.0             0              1          Yes
# 1     51676  Female  61.0             0              0          Yes
# 2     31112    Male  80.0             0              1          Yes
# 3     60182  Female  49.0             0              0          Yes
# 4      1665  Female  79.0             1              0          Yes
# ...     ...     ...   ...           ...            ...          ...
# 5105  18234  Female  80.0             1              0          Yes
# 5106  44873  Female  81.0             0              0          Yes
# 5107  19723  Female  35.0             0              0          Yes
# 5108  37544    Male  51.0             0              0          Yes
# 5109  44679  Female  44.0             0              0          Yes
#
#           work_type Residence_type  avg_glucose_level   bmi   smoking_status  \
# ...

# %%
df["bmi"] = df["bmi"].fillna(0)

# %%
df
# Out:
#          id  gender   age  hypertension  heart_disease ever_married  \
# 0      9046    Male  67.0             0              1          Yes
# 1     51676  Female  61.0             0              0          Yes
# 2     31112    Male  80.0             0              1          Yes
# 3     60182  Female  49.0             0              0          Yes
# 4      1665  Female  79.0             1              0          Yes
# ...     ...     ...   ...           ...            ...          ...
# 5105  18234  Female  80.0             1              0          Yes
# 5106  44873  Female  81.0             0              0          Yes
# 5107  19723  Female  35.0             0              0          Yes
# 5108  37544    Male  51.0             0              0          Yes
# 5109  44679  Female  44.0             0              0          Yes
#
#           work_type Residence_type  avg_glucose_level   bmi   smoking_status  \
# ...

# %%
s = 0
for i in range(5110):
    s += df["bmi"][i]
s
# Out:
# 141836.90000000005

# %%
mean = int(s / len(df["bmi"]))

# %%
mean
# Out:
# 27

# %%
for i in range(5110):
    if (df["bmi"][i] == 0):
        df["bmi"][i] = mean
df
# Out:
# <ipython-input-13-c3caebc26764>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["bmi"][i] = mean
#          id  gender   age  hypertension  heart_disease ever_married  \
# 0      9046    Male  67.0             0              1          Yes
# 1     51676  Female  61.0             0              0          Yes
# 2     31112    Male  80.0             0              1          Yes
# 3     60182  Female  49.0             0              0          Yes
# 4      1665  Female  79.0             1              0          Yes
# ...     ...     ...   ...           ...            ...          ...
# 5105  18234  Female  80.0             1              0          Yes
# 5106  44873  Female  81.0             0              0          Yes
# 5107  19723  Female  35.0             0              0          Yes
# ...

# %%
df = df.drop(columns = "id")

# %%
df
# Out:
#       gender   age  hypertension  heart_disease ever_married      work_type  \
# 0       Male  67.0             0              1          Yes        Private
# 1     Female  61.0             0              0          Yes  Self-employed
# 2       Male  80.0             0              1          Yes        Private
# 3     Female  49.0             0              0          Yes        Private
# 4     Female  79.0             1              0          Yes  Self-employed
# ...      ...   ...           ...            ...          ...            ...
# 5105  Female  80.0             1              0          Yes        Private
# 5106  Female  81.0             0              0          Yes  Self-employed
# 5107  Female  35.0             0              0          Yes  Self-employed
# 5108    Male  51.0             0              0          Yes        Private
# 5109  Female  44.0             0              0          Yes       Govt_job
#
# ...

# %%
len(df["ever_married"])
# Out:
# 5110

# %%
c = 0
for i in range(5110):
    if df["ever_married"][i] == "No":
        df["ever_married"][i] = 0
    elif df["ever_married"][i] == "Yes":
        df["ever_married"][i] = 1
# Out:
# <ipython-input-17-c14ca73c9dfd>:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["ever_married"][i] = 1
# <ipython-input-17-c14ca73c9dfd>:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["ever_married"][i] = 0

# %%
cy = 0
cn = 0
for i in range(5110):
    if(df["ever_married"][i]) == 1:
        cy += 1
    elif(df["ever_married"][i]) == 0:
        cn += 1
print(cy)
print(cn)
# Out:
# 3353
# 1757

# %%
df
# Out:
#       gender   age  hypertension  heart_disease ever_married      work_type  \
# 0       Male  67.0             0              1            1        Private
# 1     Female  61.0             0              0            1  Self-employed
# 2       Male  80.0             0              1            1        Private
# 3     Female  49.0             0              0            1        Private
# 4     Female  79.0             1              0            1  Self-employed
# ...      ...   ...           ...            ...          ...            ...
# 5105  Female  80.0             1              0            1        Private
# 5106  Female  81.0             0              0            1  Self-employed
# 5107  Female  35.0             0              0            1  Self-employed
# 5108    Male  51.0             0              0            1        Private
# 5109  Female  44.0             0              0            1       Govt_job
#
# ...

# %%
for i in range(5110):
    if (df["Residence_type"][i]) == "Urban":
        df["Residence_type"][i] = 1
    elif (df["Residence_type"][i]) == "Rural":
        df["Residence_type"][i] = 0
# Out:
# <ipython-input-20-55db1e8fbd56>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["Residence_type"][i] = 1
# <ipython-input-20-55db1e8fbd56>:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["Residence_type"][i] = 0

# %%
df
# Out:
#       gender   age  hypertension  heart_disease ever_married      work_type  \
# 0       Male  67.0             0              1            1        Private
# 1     Female  61.0             0              0            1  Self-employed
# 2       Male  80.0             0              1            1        Private
# 3     Female  49.0             0              0            1        Private
# 4     Female  79.0             1              0            1  Self-employed
# ...      ...   ...           ...            ...          ...            ...
# 5105  Female  80.0             1              0            1        Private
# 5106  Female  81.0             0              0            1  Self-employed
# 5107  Female  35.0             0              0            1  Self-employed
# 5108    Male  51.0             0              0            1        Private
# 5109  Female  44.0             0              0            1       Govt_job
#
# ...

# %%
for i in range(5110):
    if df["smoking_status"][i] == "never smoked":
        df["smoking_status"][i] = 0
    elif df["smoking_status"][i] == "formerly smoked":
        df["smoking_status"][i] = 1
    elif df["smoking_status"][i] == "smokes":
        df["smoking_status"][i] = 2
# Out:
# <ipython-input-22-463534cd878a>:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["smoking_status"][i] = 1
# <ipython-input-22-463534cd878a>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["smoking_status"][i] = 0
# <ipython-input-22-463534cd878a>:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["smoking_status"][i] = 2

# %%
df
# Out:
#       gender   age  hypertension  heart_disease ever_married      work_type  \
# 0       Male  67.0             0              1            1        Private
# 1     Female  61.0             0              0            1  Self-employed
# 2       Male  80.0             0              1            1        Private
# 3     Female  49.0             0              0            1        Private
# 4     Female  79.0             1              0            1  Self-employed
# ...      ...   ...           ...            ...          ...            ...
# 5105  Female  80.0             1              0            1        Private
# 5106  Female  81.0             0              0            1  Self-employed
# 5107  Female  35.0             0              0            1  Self-employed
# 5108    Male  51.0             0              0            1        Private
# 5109  Female  44.0             0              0            1       Govt_job
#
# ...

# %%
for i in range(5110):
    if df["work_type"][i] == "Private":
        df["work_type"][i] = 0
    elif df["work_type"][i] == "Self-employed":
        df["work_type"][i] = 1
    elif df["work_type"][i] == "Govt_job":
        df["work_type"][i] = 2
    elif df["work_type"][i] == "children":
        df["work_type"][i] = 3
    elif df["work_type"][i] == "Never_worked":
        df["work_type"][i] = 4
# Out:
# <ipython-input-24-f5f0e06de09f>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["work_type"][i] = 0
# <ipython-input-24-f5f0e06de09f>:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["work_type"][i] = 1
# <ipython-input-24-f5f0e06de09f>:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["work_type"][i] = 2
# <ipython-input-24-f5f0e06de09f>:9: SettingWithCopyWarning:
# ...

# %%
df
# Out:
#       gender   age  hypertension  heart_disease ever_married work_type  \
# 0       Male  67.0             0              1            1         0
# 1     Female  61.0             0              0            1         1
# 2       Male  80.0             0              1            1         0
# 3     Female  49.0             0              0            1         0
# 4     Female  79.0             1              0            1         1
# ...      ...   ...           ...            ...          ...       ...
# 5105  Female  80.0             1              0            1         0
# 5106  Female  81.0             0              0            1         1
# 5107  Female  35.0             0              0            1         1
# 5108    Male  51.0             0              0            1         0
# 5109  Female  44.0             0              0            1         2
#
#      Residence_type  avg_glucose_level   bmi smoking_status  stroke
# ...

# %%
for i in range(5110):
    if df["smoking_status"][i] == "Unknown":
        df["smoking_status"][i] = 0
# Out:
# <ipython-input-26-170dc8087c4e>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["smoking_status"][i] = 0

# %%
df
# Out:
#       gender   age  hypertension  heart_disease ever_married work_type  \
# 0       Male  67.0             0              1            1         0
# 1     Female  61.0             0              0            1         1
# 2       Male  80.0             0              1            1         0
# 3     Female  49.0             0              0            1         0
# 4     Female  79.0             1              0            1         1
# ...      ...   ...           ...            ...          ...       ...
# 5105  Female  80.0             1              0            1         0
# 5106  Female  81.0             0              0            1         1
# 5107  Female  35.0             0              0            1         1
# 5108    Male  51.0             0              0            1         0
# 5109  Female  44.0             0              0            1         2
#
#      Residence_type  avg_glucose_level   bmi smoking_status  stroke
# ...

# %%
for i in range(5110):
    if df["gender"][i] == "Male":
        df["gender"][i] = 0
    elif df["gender"][i] == "Female":
        df["gender"][i] = 1
    elif df["gender"][i] == "Other":
        df["gender"][i] = 2
# Out:
# <ipython-input-28-319fee095d3c>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["gender"][i] = 0
# <ipython-input-28-319fee095d3c>:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["gender"][i] = 1
# <ipython-input-28-319fee095d3c>:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["gender"][i] = 2

# %%
df
# Out:
#      gender   age  hypertension  heart_disease ever_married work_type  \
# 0         0  67.0             0              1            1         0
# 1         1  61.0             0              0            1         1
# 2         0  80.0             0              1            1         0
# 3         1  49.0             0              0            1         0
# 4         1  79.0             1              0            1         1
# ...     ...   ...           ...            ...          ...       ...
# 5105      1  80.0             1              0            1         0
# 5106      1  81.0             0              0            1         1
# 5107      1  35.0             0              0            1         1
# 5108      0  51.0             0              0            1         0
# 5109      1  44.0             0              0            1         2
#
#      Residence_type  avg_glucose_level   bmi smoking_status  stroke
# ...

# %%
y = df["stroke"]

# %%
y = y.values

# %%
y
# Out:
# array([1, 1, 1, ..., 0, 0, 0], dtype=int64)

# %%
x = df.drop(columns = "stroke")

# %%
x = x.values

# %%
x
# Out:
# array([[0, 67.0, 0, ..., 228.69, 36.6, 1],
#        [1, 61.0, 0, ..., 202.21, 27.0, 0],
#        [0, 80.0, 0, ..., 105.92, 32.5, 0],
#        ...,
#        [1, 35.0, 0, ..., 82.99, 30.6, 0],
#        [0, 51.0, 0, ..., 166.29, 25.6, 1],
#        [1, 44.0, 0, ..., 85.28, 26.2, 0]], dtype=object)

# %%
from sklearn.model_selection import train_test_split
x_train , x_test , y_train , y_test = train_test_split(x , y , test_size = 0.2)

# %%
from sklearn.linear_model import LogisticRegression

# %%
model = LogisticRegression()

# %%
model.fit(x_train , y_train)
# Out:
# c:\python 39\lib\site-packages\sklearn\linear_model\_logistic.py:763: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# LogisticRegression()

# %%
score = model.score(x_test , y_test)
print("Logestic Model Score = " , score)
# Out:
# Logestic Model Score =  0.958904109589041

# %%
from sklearn.model_selection import KFold
from sklearn.model_selection import cross_val_score
from sklearn.ensemble import RandomForestClassifier
from sklearn.svm import SVC
from sklearn.naive_bayes import GaussianNB
from sklearn.naive_bayes import MultinomialNB
from sklearn.naive_bayes import BernoulliNB

# %%
kf = KFold(n_splits = 10)

# %%
Scores_Random = cross_val_score(RandomForestClassifier() , x , y)
Scores_Gaussian = cross_val_score(GaussianNB() , x , y)
Scores_svc = cross_val_score(SVC() , x , y)

# %%
Scores_Gaussian
# Out:
# array([0.86888454, 0.85714286, 0.85714286, 0.86497065, 0.88454012])

# %%
Scores_Random
# Out:
# array([0.95009785, 0.94911937, 0.9481409 , 0.94911937, 0.95009785])

# %%
Scores_svc
# Out:
# array([0.95107632, 0.95107632, 0.95107632, 0.95107632, 0.95205479])

# %% [markdown]
# # From KFold method method Random Forest seems to do better

# %%
model = SVC()

# %%
model.fit(x_train , y_train)
# Out:
# SVC()

# %%
model.score(x_test , y_test)
# Out:
# 0.9608610567514677

# %%
y_pred = model.predict(x_test)

# %%
y_pred
# Out:
# array([0, 0, 0, ..., 0, 0, 0], dtype=int64)

# %%
y_test
# Out:
# array([0, 0, 0, ..., 0, 0, 0], dtype=int64)

# %%
wrong = 0
for i in range(len(y_test)):
    if (y_pred[i] != y_test[i]):
        wrong += 1

wrong
# Out:
# 40

# %%
len(y_test)
# Out:
# 1022

# %%
len(y_pred)
# Out:
# 1022

# %%
y_test
# Out:
# array([0, 0, 0, ..., 0, 0, 0], dtype=int64)

# %%
ans = model.predict([[1 , 8 , 1 , 1, 1, 1, 1, 228.9 , 36.5, 3]])

# %%
y_pred = model.predict(x_test)

# %%
y_pred
# Out:
# array([0, 0, 0, ..., 0, 0, 0], dtype=int64)

# %%
y_test
# Out:
# array([0, 0, 0, ..., 0, 0, 0], dtype=int64)

# %%
c = 0
for i in range(len(y_test)):
    if (y_pred[i] == y_test[i]):
        c += 1

print("No of Correct prediction = " , c)
# Out:
# No of Correct prediction =  982

# %%
import pickle
model
# Out:
# SVC()

# %%
pickle.dump(model , open("model.pkl" , 'wb'))
